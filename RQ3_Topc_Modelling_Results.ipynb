# %% [markdown]
# <a href="https://colab.research.google.com/github/ayamlearning/masters_thesis_model_final/blob/main/RQ3_Topc_Modelling_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install bertopic

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import time
from matplotlib import pyplot as plt
from datetime import datetime
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
import re
import joblib

# %%
path = "https://raw.githubusercontent.com/ayamlearning/masters_thesis_model_final/main/data/sample.csv"
df = pd.read_csv(path,delimiter=",",dtype=str)

# %%
g_path = "/content/drive/MyDrive/models"

# %%
negative_topic_model = BERTopic.load(g_path+"/model_negative.bin")
neutral_topic_model = BERTopic.load(g_path+"/model_neutral.bin")
positive_topic_model = BERTopic.load(g_path+"/model_positive.bin")

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #Neutral Sentiments

# %%
df_query = df.query("vader_polarity == '{}'".format("Neutral"))
docs = list(map(str,  df_query['prep_text']))


df_query.text = df_query.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
df_query.text = df_query.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
df_query.text = df_query.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
timestamps = df_query.date.to_list()
tweets = df_query.text.to_list()

# %%
neutral_topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cf98f45d-79e1-4030-aeb4-b4046678b791" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf98f45d-79e1-4030-aeb4-b4046678b791")) {                    Plotly.newPlot(                        "cf98f45d-79e1-4030-aeb4-b4046678b791",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.016794489860445235,0.02156060003117485,0.025227871389453625,0.029620110806924466,0.03813816515034129],"y":["30  ","million  ","register  ","voter  ","registration  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.017781318896606793,0.01835310171721804,0.021082661014511075,0.021153327414694473,0.026767030810562607],"y":["kambwili  ","walk  ","suspension  ","reconciliation  ","kanyama  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.011648454068581353,0.012749178023723199,0.014319390734453522,0.015853134077923048,0.027582221500257957],"y":["zambia  ","era  ","general  ","beckons  ","2021  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013610587412354479,0.013662953305976293,0.020176415734601917,0.027352182703330875,0.0483398820647061],"y":["news  ","politics  ","president  ","edgar  ","lungu  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.015278629190151603,0.020639097341592284,0.03396393659022716,0.047773779591042495,0.06254985356074436],"y":["guideline  ","health  ","pandemic  ","covid  ","covid19  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.037474030149523434,0.04313070857436302,0.04407111298592136,0.054354289898842306,0.05622998816392533],"y":["zambian  ","read  ","story  ","politics  ","news  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01726058928844425,0.017470791591155777,0.01902349833462062,0.04066340023635189,0.05179109578982778],"y":["term  ","chagwa  ","president  ","edgar  ","lungu  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01474609783146372,0.016762864551237638,0.02150637233603531,0.02370117890296782,0.03144121387897079],"y":["commence  ","exercise  ","voter  ","registration  ","register  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[ ...

# %%
topics_over_time = neutral_topic_model.topics_over_time(tweets, timestamps, nr_bins=20)
tt =neutral_topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=8)
tt
# Out:
# 20it [00:04,  4.72it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="acd289f2-f5e7-4ed8-9148-fe3317b50aba" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acd289f2-f5e7-4ed8-9148-fe3317b50aba")) {                    Plotly.newPlot(                        "acd289f2-f5e7-4ed8-9148-fe3317b50aba",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: nipa, unable, deceased, saw, found","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: zambiadecides, accorded, lto, ineligible, independently","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: exhibition, captured, kit, used, registration","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: querries, search, telephone, mayor, institutional","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: strategic, interface, intends, implemented, elections","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: zambiadecides, elections, engagement, announce, days","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: registration, prescribed, pali, suitable, alternatively","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: days, registration, online, voter, zambiadecides","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: days, registration, register, million, voter","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: days, registration, million, register, voter","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: registration, verify, zambiadecides, defranchised, register","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: days, kwangala, uku, choosing, registration"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_registration_voter_register_million","x":["2016-09-11T11:43:43.108000+02:00","2016-12-11T23:14:04.600000+02:00","2018-03-05T09:31:07.600000+02:00","2018-06-03T01:58:32.200000+02:00","2018-11-29T10:53:21.400000+02:00","2019-11-23T04:42:59.800000+02:00","2020-02-20T21:10:24.400000+02:00","2020-05-20T13:37:49+02:00","2020-08-18T06:05:13.600000+02:00","2020-11-15T22:32:38.200000+02:00","2021-02-13T15:00:02.800000+02:00","2021-05-14T07:27:27.400000+02:00"],"y":[1,4,1,4,2,3,8,36,147,41,15,12],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: zambiadecides, prince, namwala, restoration, zra","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: solwezi, coming, kanyama, reconciliation, suspension","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: comic, cartoon, sketch, literary, imitation","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: kanye, wanga, muntu, follow, would","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: nshima, subject, tread, abour, medias","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: dislodged, nonviolent, figurehead, theatre, nkwazi","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: sata, chanda, nembwa, sandler, abakote","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: kachilaba, kalebomfya, twanaka, kweshen, mambala","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: priscilla, vs, pick, nonononono, zagaze","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: tabakapite, zambiadecides, alone, ba, umbi","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: conscious, iris, zambiadecides, label, uncanny","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: kalabi, reconciliation, walk, peace, women","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: zambiadecides, kanyama, suspension, kambwili, chishimba"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_kanyama_reconcilia ...

# %%
reduced_embeddings = joblib.load(g_path+"/neutral_umap_model.pkl")
neutral_topic_model.visualize_documents(docs, reduced_embeddings=reduced_embeddings)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="51b78f4f-0ce6-4102-82c3-1c5466daffae" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51b78f4f-0ce6-4102-82c3-1c5466daffae")) {                    Plotly.newPlot(                        "51b78f4f-0ce6-4102-82c3-1c5466daffae",                        [{"hoverinfo":"text","hovertext":["someone feeling economic hardship tired best capitalize opportunity election season present dream shattered pf youth","new frontier wa beginning used kenya 2017 election wa headline zambia sister company contracted opposition","typical sir","sata reached mass time 2011 election sir come compound see terrible thing offer hope people see sata queuing shoprite cheap bread mealie meal depressing moment zambia","share pf vote","thank everyone joined network unstable end question contribution leave","let coincidence mealie meal election hunger zambia purpose mealie meal chilubi","early 1990s zambia political landscape changed yet country holding first multiparty election october 1991 advent multiparty politics ushered third republic era economic liberalisation","prepping sister team cover 2021 zambian election august","type lawlessness continue another 5 year please vote change thursday","exactly 365 day election","malawi south africa tanzania zambia zim mdct coward running father ed begging evade election kuroya broad daylight coz know national election leave exposed impostor clown","coward respond zambian see","constitution provision former president refuse handover powerif edgar chagwa lungu refuse handover power military know 12th august 2021 tripartite electionslungu complete power transition","cpj demand unconditional reopening muvi tv 2 broadcaster","true especially politician never learn history","kampyongo upnd hired foreigner interfere election kind difficult interfere election control state apparatus","political leader advised controlled called cadre possible 4 take action","presidential election malawi ahead 19 may","online nope let stick voting system know idea giving u leader vote entertained","met today discussing","unip","true life matter alm","mwandi resident must elect candidate council chairpersonpf","voting lusaka zambia vote roksie","postponement please anything wish would announce voting year next year kwalepa please olo ce presidential election yeka fye vote soon yesterday","call openness","reason sold pink people either","ask question remembering promise give headache guy lie africa","eu present final report 2016 election including recommendation future election zambia","electoral commission 2021 election roadmap politicization electoral system equally tribalization ethnicization regionalization","exactly doe advantage pf disillusioned voter voting regardless number constituency","zambia democracy increasing strain country head august election read new assessment key issue watch","chomabased human right activist bright jalila election zambia become risky event citizen opposed democratic exercise interview jalila said","copied","03 waiting everyone house ready","electoral commission zambia legal mandate postpone 2021 general election","zesco powerless power present blood lordshed","zambia wake saw today wa danger miltants cadre determined stifle democracy police force need non partisan neutral vigilant month ahead election cadre thug deserve place","please confirm accreditation period extended 10th august 2021","electoral corruption good zambia democracy father leonard chiti","told zambian investigating people behind gassing till","soaring food price economic hardship could sway week tightlycontested zambian presidential vote favour opposition citizen grapple fallout rampant financial mismanagement","little week election  ...

# %%
neutral_topic_model.visualize_hierarchy(top_n_topics=7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2acee64-4481-46cd-96a9-cf7616b1c5b4" class="plotly-graph-div" style="height:305px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2acee64-4481-46cd-96a9-cf7616b1c5b4")) {                    Plotly.newPlot(                        "c2acee64-4481-46cd-96a9-cf7616b1c5b4",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5851511757523982,0.5851511757523982,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9102943466346668,0.9102943466346668,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8579319349252186,0.8579319349252186,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8967664956560907,0.8967664956560907,0.8579319349252186],"xaxis":"x","y":[-45.0,-45.0,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9102943466346668,0.9468679957434069,0.9468679957434069,0.8967664956560907],"xaxis":"x","y":[-30.0,-30.0,-52.5,-52.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.5851511757523982,1.0115808793766592,1.0115808793766592,0.9468679957434069],"xaxis":"x","y":[-10.0,-10.0,-41.25,-41.25],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":305,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["6_lungu_edgar_president","3_lungu_edgar_president","5_news_politics_story","1_kanyama_reconciliation_su...","0_registration_voter_register","2_2021_beckons_general","4_covid19_covid_pandemic"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0],"type":"linear","zeroline":false,"range":[-70.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %%
# Calculate the topic distributions on a token-level
topic_distr, topic_token_distr = neutral_topic_model.approximate_distribution(docs, calculate_tokens=True)

# Visualize the token-level distributions
neutral_topic_model.visualize_approximate_distribution(docs[1], topic_token_distr[1])
# Out:
# 100%|██████████| 13/13 [00:04<00:00,  3.03it/s]
# <style type="text/css">
# #T_45b26_row0_col0, #T_45b26_row3_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row0_col1, #T_45b26_row0_col2, #T_45b26_row0_col3, #T_45b26_row10_col4 {
#   background-color: #77b5d9;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row0_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row0_col5, #T_45b26_row0_col6, #T_45b26_row0_col7, #T_45b26_row0_col8, #T_45b26_row0_col9, #T_45b26_row0_col10, #T_45b26_row0_col11, #T_45b26_row0_col12, #T_45b26_row1_col0, #T_45b26_row1_col1, #T_45b26_row1_col2, #T_45b26_row1_col3, #T_45b26_row1_col4, #T_45b26_row1_col5, #T_45b26_row1_col6, #T_45b26_row1_col7, #T_45b26_row1_col8, #T_45b26_row2_col4, #T_45b26_row2_col5, #T_45b26_row2_col6, #T_45b26_row2_col7, #T_45b26_row2_col8, #T_45b26_row2_col9, #T_45b26_row2_col10, #T_45b26_row2_col11, #T_45b26_row2_col12, #T_45b26_row3_col6, #T_45b26_row3_col7, #T_45b26_row3_col8, #T_45b26_row3_col9, #T_45b26_row3_col10, #T_45b26_row3_col11, #T_45b26_row3_col12, #T_45b26_row4_col0, #T_45b26_row4_col1, #T_45b26_row4_col2, #T_45b26_row4_col3, #T_45b26_row4_col4, #T_45b26_row4_col5, #T_45b26_row5_col4, #T_45b26_row5_col5, #T_45b26_row5_col6, #T_45b26_row5_col7, #T_45b26_row5_col8, #T_45b26_row5_col9, #T_45b26_row5_col10, #T_45b26_row5_col11, #T_45b26_row5_col12, #T_45b26_row6_col5, #T_45b26_row6_col6, #T_45b26_row6_col7, #T_45b26_row6_col8, #T_45b26_row6_col9, #T_45b26_row6_col10, #T_45b26_row6_col11, #T_45b26_row6_col12, #T_45b26_row7_col5, #T_45b26_row7_col6, #T_45b26_row7_col7, #T_45b26_row7_col8, #T_45b26_row7_col9, #T_45b26_row7_col10, #T_45b26_row7_col11, #T_45b26_row7_col12, #T_45b26_row8_col6, #T_45b26_row8_col7, #T_45b26_row8_col8, #T_45b26_row8_col9, #T_45b26_row8_col10, #T_45b26_row8_col11, #T_45b26_row8_col12, #T_45b26_row9_col7, #T_45b26_row9_col8, #T_45b26_row9_col9, #T_45b26_row9_col10, #T_45b26_row9_col11, #T_45b26_row9_col12, #T_45b26_row10_col6, #T_45b26_row10_col7, #T_45b26_row10_col8, #T_45b26_row10_col9, #T_45b26_row10_col10, #T_45b26_row10_col11, #T_45b26_row10_col12 {
#   background-color: #f7fbff;
#   color: #000000;
#   color: white;
#   background-color: white;
# }
# #T_45b26_row1_col9, #T_45b26_row1_col10, #T_45b26_row1_col11, #T_45b26_row1_col12 {
#   background-color: #d4e4f4;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row2_col0, #T_45b26_row2_col1, #T_45b26_row2_col2, #T_45b26_row2_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row3_col0 {
#   background-color: #cbdef1;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row3_col1 {
#   background-color: #95c5df;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row3_col2, #T_45b26_row3_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row3_col5 {
#   background-color: #ddeaf7;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row4_col6 {
#   background-color: #dae8f6;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row4_col7 {
#   background-color: #afd1e7;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row4_col8 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row4_col9 {
#   background-color: #3585bf;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row4_col10 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row4_col11, #T_45b26_row9_col0 {
#   background-color: #a6cee4;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row4_col12 {
#   background-color: #d6e5f4;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row5_col0, #T_45b26_row5_col1, #T_45b26_row5_col2, #T_45b26_row5_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row6_col0 {
#   background-color: #cde0f1;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row6_col1, #T_45b26_row6_col2, #T_45b26_row6_col3 {
#   background-color: #9fcae1;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row6_col4 {
#   background-color: #d7e6f5;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row7_col0, #T_45b26_row8_col5 {
#   background-color: #caddf0;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row7_col1, #T_45b26_row7_col2, #T_45b26_row7_col3 {
#   background-color: #9dcae1;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row7_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row8_col0 {
#   background-color: #91c3de;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row8_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row8_col2, #T_45b26_row8_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row8_col4 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row9_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row9_col2 {
#   background-color: #1460a8;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row9_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row9_col4 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row9_col5 {
#   background-color: #99c7e0;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row9_col6 {
#   background-color: #d3e3f3;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row10_col0 {
#   background-color: #a5cde3;
#   color: #000000;
#   color: black;
# }
# #T_45b26_row10_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row10_col2, #T_45b26_row10_col3 {
#   background-color: #125ea6;
#   color: #f1f1f1;
#   color: black;
# }
# #T_45b26_row10_col5 {
#   background-color: #cfe1f2;
#   color: #000000;
#   color: black;
# }
# </style>
# <table id="T_45b26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45b26_level0_col0" class="col_heading level0 col0" >day</th>
#       <th id="T_45b26_level0_col1" class="col_heading level0 col1" >left </th>
#       <th id="T_45b26_level0_col2" class="col_heading level0 col2" >remember  </th>
#       <th id="T_45b26_level0_col3" class="col_heading level0 col3" >keep   </th>
#       <th id="T_45b26_level0_col4" class="col_heading level0 col4" >best    </th>
#       <th id="T_45b26_level0_col5" class="col_heading level0 col5" >attitude     </th>
#       <th id="T_45b26_level0_col6" class="col_heading level0 col6" >avoid      </th>
#       <th id="T_45b26_level0_col7" class="col_heading level0 col7" >getting       </th>
#       <th id="T_45b26_level0_col8" class="col_heading level0 col8" >conflict        </th>
#       <th id="T_45b26_level0_col9" class="col_heading level0 col9" >law         </th>
#       <th id="T_45b26_level0_col10" class="col_heading level0 col10" >vote          </th>
#       <th id="T_45b26_level0_col11" class="col_heading level0 col11" >count           </th>
#       <th id="T_45b26_level0_col12" class="col_heading level0 col12" >visiting            </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45b26_level0_row0" class="row_heading level0 row0" >13_day_remaining_till_left</th>
#       <td id="T_45b26_row0_col0" class="data row0 col0" >0.232</td>
#       <td id="T_45b26_row0_col1" class="data row0 col1" >0.360</td>
#       <td id="T_45b26_row0_col2" class="data row0 col2" >0.360</td>
#       <td id="T_45b26_row0_col3" class="data row0 col3" >0.360</td>
#       <td id="T_45b26_row0_col4" class="data row0 col4" >0.128</td>
#       <td id="T_45b26_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_45b26_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_45b26_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_45b26_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_45b26_row0_col9" class="data row0 col9" >0.000</td>
#       <td id="T_45b26_row0_col10" class="data row0 col10" >0.000</td>
#       <td id="T_45b26_row0_col11" class="data row0 col11" >0.000</td>
#       <td id="T_45b26_row0_col12" class="data row0 col12" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_45b26_level0_row1" class="row_heading level0 row1" >87_voice_alot_task_micomyizajohn</th>
#       <td id="T_45b26_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_45b26_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_

# %%
pd.DataFrame(neutral_topic_model.get_topic(0),columns=["Word","Score"])
# Out:
#            Word     Score
# 0  registration  0.038138
# 1         voter  0.029620
# 2      register  0.025228
# 3       million  0.021561
# 4            30  0.016794
# 5        online  0.012248
# 6        period  0.011726
# 7    registered  0.010651
# 8           day  0.010298
# 9          2020  0.010279

# %% [markdown]
# ## **Negative** Sentiments

# %%
df_query = df.query("vader_polarity == '{}'".format("Negative"))
docs = list(map(str,  df_query['prep_text']))

df_query.text = df_query.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
df_query.text = df_query.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
df_query.text = df_query.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
timestamps = df_query.date.to_list()
tweets = df_query.text.to_list()

# %%
negative_topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f4568c4c-5e3a-4481-b1c0-35db8c681c0e" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4568c4c-5e3a-4481-b1c0-35db8c681c0e")) {                    Plotly.newPlot(                        "f4568c4c-5e3a-4481-b1c0-35db8c681c0e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.029275742908748466,0.02967951171011004,0.03033049778935442,0.05654483035285915,0.06242262935051764],"y":["vote  ","people  ","pf  ","zambia  ","election  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.2354395584930128,0.23581255813548765,0.23581255813548765,0.23581255813548765,0.3753405312060393],"y":["delayed  ","impasse  ","sexual  ","drama  ","africa  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.30073201907665437,0.33043812271046225,0.34420374973982576,0.3540909198098528,0.36434504724293415],"y":["army  ","violence  ","deploys  ","ahead  ","curb  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.26946033443817013,0.28973323803765544,0.34551303859243176,0.38267450374923556,0.5679128680470178],"y":["parent  ","electoral  ","violence  ","demonstrate  ","youth  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...

# %%
topics_over_time = negative_topic_model.topics_over_time(tweets, timestamps, nr_bins=20)
tt =negative_topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=8)
tt
# Out:
# 20it [00:00, 36.10it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6952e3f2-8c36-4ad3-a1a6-dc04d440a0b2" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6952e3f2-8c36-4ad3-a1a6-dc04d440a0b2")) {                    Plotly.newPlot(                        "6952e3f2-8c36-4ad3-a1a6-dc04d440a0b2",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, election, opposition, european","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hh, upnd, zambia, police, lungu","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, lungu, pf, lose","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, drc, emergency, sa","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, morpho, ghurair, nigeria","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, president, person, parliament","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, violence, election, commission","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, zimbabwe, election, opposition","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, lost, pf, chinese","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, election, sesheke, pf","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, ecz, people, vote","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, kamanga, samir, caf","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, people, election, violence","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, pf, lungu, election","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, people, election, pf","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, ecz, election, lungu","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, ecz, election, voter","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, august, election, people","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, pf, election, people","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, zambia, politics, election, pf"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_election_zambia_pf_people","x":["2016-09-11T19:40:54.476000+02:00","2016-12-12T06:47:09.200000+02:00","2017-03-11T22:50:55.400000+02:00","2017-06-09T14:54:41.600000+02:00","2017-09-07T06:58:27.800000+02:00","2017-12-05T23:02:14+02:00","2018-03-05T15:06:00.200000+02:00","2018-06-03T07:09:46.400000+02:00","2018-08-31T23:13:32.600000+02:00","2018-11-29T15:17:18.800000+02:00","2019-02-27T07:21:05+02:00","2019-05-27T23:24:51.200000+02:00","2019-08-25T15:28:37.400000+02:00","2019-11-23T07:32:23.600000+02:00","2020-02-20T23:36:09.800000+02:00","2020-05-20T15:39:56+02:00","2020-08-18T07:43:42.200000+02:00","2020-11-15T23:47:28.400000+02:00","2021-02-13T15:51:14.600000+02:00","2021-05-14T07:55:00.800000+02:00"],"y":[34,87,21,22,15,21,32,62,27,43,40,23,61,324,95,159,340,215,181,974],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: africa, sexual, drama, impasse, delayed","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: africa, sexual, drama, impasse, delayed"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_africa_drama_sexual_impasse","x":["2020-05-20T15:39:56+02:00","2020-08-18T07:43:42.200000+02:00"],"y":[56,83],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopi ...

# %%
reduced_embeddings = joblib.load(g_path+"/negative_umap_model.pkl")
negative_topic_model.visualize_documents(docs, reduced_embeddings=reduced_embeddings)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d34c795-7b63-4f22-b8a1-d830fcf27319" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d34c795-7b63-4f22-b8a1-d830fcf27319")) {                    Plotly.newPlot(                        "5d34c795-7b63-4f22-b8a1-d830fcf27319",                        [{"hoverinfo":"text","hovertext":[null],"marker":{"color":"#CFD8DC","opacity":0.5,"size":5},"mode":"markers+text","name":"other","showlegend":false,"x":[null],"y":[null],"type":"scattergl"},{"hoverinfo":"text","hovertext":["chishimba kambwili condemns upnd cadre attack sinazongwe teacher","pf know even campaign period record beating people street marketplace bus stop think duty police arrest removing campaign poster yesterday pf cadre removed upnd flag lumumba road","tomorrow fire hire","subject tribe grz recently retired tonga man national interestsince yet cleared still payroll replacement also pay paying 2 people 1 position grz complaining bloated payroll stupid people","hike rate note fx reserve 14bn 157bn end 2018 external debt service cost 90 year stay high 202021 continue drain buffer worry govt doe act try make 2021 election","chawama shock man rape sick grandma zambian politics news read","let u allow anything ecz throw u discourage u let register vote change lot take charge people put system electoral system 2005 nshindano others decided discard","gambia kenya nigeria tunisia uganda zambia zimbabwe suspended subnational election ethiopia postponed national poll earlymay south africa electoral commission wa delaying 30 municipal byelection","ruling party hv always taken advantage poverty illiteracy vast rural area poor people swing vote favour unless upnd seriously reflect aspect fear pf rigging 2021 election rural zambia big time unfortunately status quo change","prison commissioner general chileshe tasked ensure eligible prisoner vote lungu chileshe promised 100 prison vote ecl threatening prisoner consequence vote lungu","another hallmark democracy substantive outcome uncertainty predetermined outcome thing seen ought","ethan zulu chief chikanta tonga speaking people kalomo district southern province urged zambia police arrest anyone scheming violence august 12th general election chief","cocktail civil war brewed mass poverty restless violent party cadre rigged election desperate political elite collapsed government civil war dangerous end lungu co taking u","biggest enemy nation right mr recipe anarchy ahead august election need watch closely","agreed bill gate warned youth boom without job hope global critical upnd work youth draft solution youth empowerment avoid gate doomsday prediction","electoral commission zambia weak people must rise demand balance electoral process clear president campaigning 2021 election opposition allowed balance whole process blame ecz","election zambia always credible loser make noise","said chartered flight ballot paper dubai infinix appear claiming ownership erroneous phone seem claim wa regular cargo flight one two party lying","1st ecl personal raised salary 2nd began abuse office president 3rd collapsed judiciary 4th caused countless death 5th tolerated corruption theft abuse authority violation human right lawlessness etc list endless","shamble need vote wisely chaotic party lead peaceful pf win election big big trouble nation people starve business shut crime rise fear","unless otherwise prisoner vote prisoner also become zambia electoral commission chairperson","unfortunate news start politicking death mhsriep","2016 riot broke upnd stronghold lungu wa announced president hakainde hichilema told supporter stop going court war wanted kill edgar lungu could done 4 year ago year election","breaking news president trump confir ...

# %%
negative_topic_model.visualize_hierarchy(top_n_topics=7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a113f386-323c-4ed6-b433-b755b389e77b" class="plotly-graph-div" style="height:260px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a113f386-323c-4ed6-b433-b755b389e77b")) {                    Plotly.newPlot(                        "a113f386-323c-4ed6-b433-b755b389e77b",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6968275132964104,0.6968275132964104,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.6968275132964104,0.9034443495739769,0.9034443495739769,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0062957763141331,1.0062957763141331,0.9034443495739769],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":260,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["1_africa_drama_sexual","2_curb_ahead_deploys","0_election_zambia_pf","3_youth_demonstrate_violence"],"tickvals":[-5.0,-15.0,-25.0,-35.0],"type":"linear","zeroline":false,"range":[-40.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777 ...

# %%
topic_distr, topic_token_distr = negative_topic_model.approximate_distribution(docs, calculate_tokens=True)
negative_topic_model.visualize_approximate_distribution(docs[1], topic_token_distr[1])
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  4.59it/s]
# Empty DataFrame
# Columns: [disappointing, see , zambia  , falling   , low    ]
# Index: []

# %%
pd.DataFrame(negative_topic_model.get_topic(0),columns=["Word","Score"])
# Out:
#        Word     Score
# 0  election  0.062423
# 1    zambia  0.056545
# 2        pf  0.030330
# 3    people  0.029680
# 4      vote  0.029276
# 5   zambian  0.025919
# 6     voter  0.022991
# 7     lungu  0.022822
# 8  violence  0.022798
# 9      2021  0.021673

# %% [markdown]
# ## POSTIVE Sentiments

# %%
df_query = df.query("vader_polarity == '{}'".format("Positive"))
docs = list(map(str,  df_query['prep_text']))

df_query.text = df_query.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
df_query.text = df_query.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
df_query.text = df_query.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
timestamps = df_query.date.to_list()
tweets = df_query.text.to_list()

# %%
positive_topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ab58896d-1aa0-4931-bec7-9f148b96315f" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab58896d-1aa0-4931-bec7-9f148b96315f")) {                    Plotly.newPlot(                        "ab58896d-1aa0-4931-bec7-9f148b96315f",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.016424613731765708,0.016629121717666173,0.020133380486337085,0.05676209987080133,0.06135072286093971],"y":["zambian  ","zambia  ","election  ","free  ","fair  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.014084900548747724,0.015867837719931548,0.03365186110899936,0.05042070521595222,0.08930995484025042],"y":["assures  ","chagwa  ","president  ","edgar  ","lungu  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.08293024523661031,0.08400937489136726,0.10436755039789135,0.10737355389139665,0.11435667939026008],"y":["alright  ","thank  ","great  ","awesome  ","thanks  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.020111640065086065,0.020266894516699066,0.02113070573665499,0.021671294552753535,0.02187785660662502],"y":["socialist  ","year  ","winner  ","attempt  ","zambia  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.023102820203584302,0.03013565035365364,0.03998997899350774,0.05005817369079286,0.060167446213588834],"y":["may  ","praying  ","prayer  ","pray  ","god  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02135059261362197,0.023831694626532136,0.024605236583573886,0.026201333941650605,0.027560542297605597],"y":["confidence  ","public  ","integrity  ","credibility  ","electoral  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.017867301284989225,0.017877446792316044,0.01860843663779055,0.021978668890498244,0.04306847453634237],"y":["tomorrow  ","bless  ","zambia  ","thank  ","vote  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03579905352190421,0.04280905297595683,0.04410907849927309,0.04938110084629577,0.07415684052629776],"y":["detail  ","voter  ","register  ","online  ","registration  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %%
topics_over_time = positive_topic_model.topics_over_time(tweets, timestamps, nr_bins=20)
positive_topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=8)
# Out:
# 20it [00:01, 12.94it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e0f118de-10b2-4c1f-8666-041f762c93ba" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0f118de-10b2-4c1f-8666-041f762c93ba")) {                    Plotly.newPlot(                        "e0f118de-10b2-4c1f-8666-041f762c93ba",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, zambians, free, promoting","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, zambians, penny, ed, promoting","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, commonwealth, credible, fair, free","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, fair, native, watchdog, free","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: laila, pulling, kenya, the, odinga","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, bafana, tunisian, nelson, uniting","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, precision, teaching, loot","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, fair, feee, turkey","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wahman, ssa, boone, sample, strengthens","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, the, seom, joseph, rsa","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ambassador, mcp, utm, the, elections","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, zambians, fair, free","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, dismisses, upholds, court, directs","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, zambians, fair, free","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, the, fair, free, hold","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: elections, the, fair, free, kamanga","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, fair, free, hakainde","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, fair, free, zambians"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_fair_free_election_zambia","x":["2016-09-11T14:41:11.612000+02:00","2016-12-12T02:02:37.400000+02:00","2017-03-11T18:21:16.800000+02:00","2017-06-09T10:39:56.200000+02:00","2017-09-07T02:58:35.600000+02:00","2018-03-05T11:35:54.400000+02:00","2018-06-03T03:54:33.800000+02:00","2018-08-31T20:13:13.200000+02:00","2018-11-29T12:31:52.600000+02:00","2019-02-27T04:50:32+02:00","2019-08-25T13:27:50.800000+02:00","2019-11-23T05:46:30.200000+02:00","2020-02-20T22:05:09.600000+02:00","2020-05-20T14:23:49+02:00","2020-08-18T06:42:28.400000+02:00","2020-11-15T23:01:07.800000+02:00","2021-02-13T15:19:47.200000+02:00","2021-05-14T07:38:26.600000+02:00"],"y":[7,5,2,4,1,2,7,3,1,3,1,7,1,6,10,7,20,43],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, lungu, bruising, commits","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: livingstone, lungu, mapani, victory, command","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: elections, adopts, motion, deregister, lungu","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: elections, chosen, lungu, help, support","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: the, teling, puted, stil, inorder","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, lungu, disable, upnd","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, drc, lungu, earn","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: the, elections, lungu, con ...

# %%
reduced_embeddings = joblib.load(g_path+"/positive_umap_model.pkl")
positive_topic_model.visualize_documents(docs, reduced_embeddings=reduced_embeddings)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0bb97f9d-7373-4699-bbd9-78742d37238d" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bb97f9d-7373-4699-bbd9-78742d37238d")) {                    Plotly.newPlot(                        "0bb97f9d-7373-4699-bbd9-78742d37238d",                        [{"hoverinfo":"text","hovertext":["slowly forgetting like moved cbu incident wonder tend amnestic syndrome election wonder wht kind forgetting gu breath zambia must strong one like 1 zambia 1 amnesia","job seeker getting ready encouraged president prepare employer kyc know candidate sdgising manifesto","like many uk excolony zambia fptp system easily delivers elective dictatorship uk also system effectively gamed using cambridge analytica psyops tool brexit vote election kenya usa","political landscape zambia shifted zambian woke zambian national pride anyone place zambian second charles banda vote zambian whoever win 2021 given chance five year","midwife association zambia annual general meeting election new office bearer next 5 year midwife","advert electoral commission zambia invitation expression interest eczsrv01317 request expression interest individual consultant lead electoral commission zambia research team cause rejected ballot paper","someone pa miss universe zambia pa need vote u famous cloud lol hence apology","big congratulation brother citi fm citi tv team much learn cover zambia 2021 election inspire ghanaian bros zambia kuodos senior","judge like chameleon support leader power need overhaul judiciary 12th august breaking news lungu eligible 2021 election constitutional court via zambian observer","zambia zuma would win election maimane malema seem vocal proud zambian hate","know thing hard zambia mayor greater city lusaka decides become network marketer unfair advantage thoughlusaka city council full network marketing product office","random uk covert action week 1950s 1960s uk covertly meddled bunch postimperial election help least undesirable available candidate eg ghana sudan tanzania nigeria zambia","nigeria network sm voting airtel mtn 9mobile please always check spelling eg vote nengi 32052 ninja namibia sa botswana zimbabwe zambia ghana malawi tanzania online vote important","even vote people talk like promoting division zambia wake","happy beloved mother stay strong rooted glorious","police watching pf break election act like wa done upnd would hv arrested swiftly pf party zambia law well protected great leader","maobane ne ke mametse ntate shale thatoloha hamonate ka sesotho tsetsetha tsa zambia warmed heart wa wa called continental expert governance election reminded actually trained u election conciliation","ucz preaches peace united church zambia ucz called politician preach peace general election read story","eating resting enough ni next week yama need healthy","sometimes experienced challenge men woman risen among u restore u back right path build hope resilient","pressure mount towards 12th august getting clear candidate attracts comfortable working vermin","let vote wisely tomorrow may peaceful election one zambia one nation","see change political arena even opposition wa win next election zambia due political leader protecting ordinary pipo different view especially cadre anything peanut","god richly bless making sierra leone icon emulation","father mother party vote child remember respect god plan always respect parent honour","saw happen post newspaper 201516 wa still believed politically motivated move slightly year zambia hold election prime television popular opposition","people poll human right vision country needed right respecting government society form vital mix prosperous country reread report human right background","remain co ...

# %%
positive_topic_model.visualize_hierarchy(top_n_topics=7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d289eec4-134e-4989-aed2-9e7990929e99" class="plotly-graph-div" style="height:305px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d289eec4-134e-4989-aed2-9e7990929e99")) {                    Plotly.newPlot(                        "d289eec4-134e-4989-aed2-9e7990929e99",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7865005572781456,0.7865005572781456,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7975942147199905,0.7975942147199905,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7813603664777562,0.7813603664777562,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7975942147199905,0.8650637266321941,0.8650637266321941,0.7813603664777562],"xaxis":"x","y":[-40.0,-40.0,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7865005572781456,0.9124262929905473,0.9124262929905473,0.8650637266321941],"xaxis":"x","y":[-20.0,-20.0,-50.0,-50.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9867268468145967,0.9867268468145967,0.9124262929905473],"xaxis":"x","y":[-5.0,-5.0,-35.0,-35.0],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":305,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["2_thanks_awesome_great","4_god_pray_prayer","6_vote_thank_zambia","1_lungu_edgar_president","3_zambia_attempt_winner","0_fair_free_election","5_electoral_credibility_int..."],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0],"type":"linear","zeroline":false,"range":[-70.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888 ...

# %%
topic_distr, topic_token_distr = positive_topic_model.approximate_distribution(docs, calculate_tokens=True)
positive_topic_model.visualize_approximate_distribution(docs[1], topic_token_distr[1])
# Out:
# 100%|██████████| 6/6 [00:01<00:00,  4.38it/s]
# <style type="text/css">
# #T_a12e7_row0_col0, #T_a12e7_row0_col1, #T_a12e7_row0_col2, #T_a12e7_row0_col3, #T_a12e7_row0_col4, #T_a12e7_row0_col5, #T_a12e7_row0_col6, #T_a12e7_row0_col7, #T_a12e7_row0_col8, #T_a12e7_row0_col9, #T_a12e7_row0_col10, #T_a12e7_row0_col11, #T_a12e7_row0_col12, #T_a12e7_row0_col21, #T_a12e7_row0_col22, #T_a12e7_row0_col23, #T_a12e7_row1_col0, #T_a12e7_row1_col1, #T_a12e7_row1_col2, #T_a12e7_row1_col3, #T_a12e7_row1_col4, #T_a12e7_row1_col5, #T_a12e7_row1_col10, #T_a12e7_row1_col11, #T_a12e7_row1_col12, #T_a12e7_row1_col13, #T_a12e7_row1_col14, #T_a12e7_row1_col15, #T_a12e7_row1_col16, #T_a12e7_row1_col17, #T_a12e7_row1_col18, #T_a12e7_row1_col19, #T_a12e7_row1_col20, #T_a12e7_row1_col21, #T_a12e7_row1_col22, #T_a12e7_row1_col23, #T_a12e7_row2_col0, #T_a12e7_row2_col1, #T_a12e7_row2_col9, #T_a12e7_row2_col10, #T_a12e7_row2_col11, #T_a12e7_row2_col12, #T_a12e7_row2_col13, #T_a12e7_row2_col14, #T_a12e7_row2_col15, #T_a12e7_row2_col16, #T_a12e7_row2_col17, #T_a12e7_row2_col18, #T_a12e7_row2_col19, #T_a12e7_row2_col20, #T_a12e7_row2_col21, #T_a12e7_row2_col22, #T_a12e7_row2_col23, #T_a12e7_row3_col6, #T_a12e7_row3_col7, #T_a12e7_row3_col8, #T_a12e7_row3_col9, #T_a12e7_row3_col10, #T_a12e7_row3_col11, #T_a12e7_row3_col12, #T_a12e7_row3_col13, #T_a12e7_row3_col14, #T_a12e7_row3_col15, #T_a12e7_row3_col16, #T_a12e7_row3_col17, #T_a12e7_row3_col18, #T_a12e7_row3_col19, #T_a12e7_row3_col20, #T_a12e7_row3_col21, #T_a12e7_row3_col22, #T_a12e7_row3_col23 {
#   background-color: #f7fbff;
#   color: #000000;
#   color: white;
#   background-color: white;
# }
# #T_a12e7_row0_col13 {
#   background-color: #d0e1f2;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row0_col14 {
#   background-color: #77b5d9;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row0_col15 {
#   background-color: #2676b8;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a12e7_row0_col16 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a12e7_row0_col17 {
#   background-color: #083776;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a12e7_row0_col18 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a12e7_row0_col19 {
#   background-color: #84bcdb;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row0_col20 {
#   background-color: #d6e5f4;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row1_col6, #T_a12e7_row1_col7, #T_a12e7_row1_col8, #T_a12e7_row1_col9, #T_a12e7_row3_col0, #T_a12e7_row3_col1 {
#   background-color: #e5eff9;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row2_col2 {
#   background-color: #dae8f6;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row2_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row2_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row2_col5 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a12e7_row2_col6 {
#   background-color: #97c6df;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row2_col7 {
#   background-color: #c4daee;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row2_col8 {
#   background-color: #dfecf7;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row3_col2, #T_a12e7_row3_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
#   color: black;
# }
# #T_a12e7_row3_col4, #T_a12e7_row3_col5 {
#   background-color: #e4eff9;
#   color: #000000;
#   color: black;
# }
# </style>
# <table id="T_a12e7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a12e7_level0_col0" class="col_heading level0 col0" >like</th>
#       <th id="T_a12e7_level0_col1" class="col_heading level0 col1" >kkia </th>
#       <th id="T_a12e7_level0_col2" class="col_heading level0 col2" >four  </th>
#       <th id="T_a12e7_level0_col3" class="col_heading level0 col3" >time   </th>
#       <th id="T_a12e7_level0_col4" class="col_heading level0 col4" >big    </th>
#       <th id="T_a12e7_level0_col5" class="col_heading level0 col5" >projected     </th>
#       <th id="T_a12e7_level0_col6" class="col_heading level0 col6" >traffic      </th>
#       <th id="T_a12e7_level0_col7" class="col_heading level0 col7" >zambia       </th>
#       <th id="T_a12e7_level0_col8" class="col_heading level0 col8" >airway        </th>
#       <th id="T_a12e7_level0_col9" class="col_heading level0 col9" >doe         </th>
#       <th id="T_a12e7_level0_col10" class="col_heading level0 col10" >take          </th>
#       <th id="T_a12e7_level0_col11" class="col_heading level0 col11" >like           </th>
#       <th id="T_a12e7_level0_col12" class="col_heading level0 col12" >seven            </th>
#       <th id="T_a12e7_level0_col13" class="col_heading level0 col13" >time             </th>
#       <th id="T_a12e7_level0_col14" class="col_heading level0 col14" >big              </th>
#       <th id="T_a12e7_level0_col15" class="col_heading level0 col15" >term               </th>
#       <th id="T_a12e7_level0_col16" class="col_heading level0 col16" >loan                </th>
#       <th id="T_a12e7_level0_col17" class="col_heading level0 col17" >china                 </th>
#       <th id="T_a12e7_level0_col18" class="col_heading level0 col18" >control                  </th>
#       <th id="T_a12e7_level0_col19" class="col_heading level0 col19" >come                   </th>
#       <th id="T_a12e7_level0_col20" class="col_heading level0 col20" >something                    </th>
#       <th id="T_a12e7_level0_col21" class="col_heading level0 col21" >like                     </th>
#       <th id="T_a12e7_level0_col22" class="col_heading level0 col22" >15                      </th>
#       <th id="T_a12e7_level0_col23" class="col_heading level0 col23" >year                       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a12e7_level0_row0" class="row_heading level0 row0" >13_loan_chinese_debt_china</th>
#       <td id="T_a12e7_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_a12e7_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_a12e7_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_a12e7_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_a12e7_row0_col4" class="data row0 col4" >0.000</td>
#       <td id="T_a12e7_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_a12e7_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_a12e7_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_a12e7_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_a12e7_row0_col9" class="data row0 col9" >0.000</td>
#       <td id="T_a12e7_row0_col10" class="data row0 col10" >0.000</td>
#       <td id="T_a12e7_row0_col11" class="data row0 col11" >0.000</td>
#       <td id="T_a12e7_row0_col12" class="data row0 col12" >0.000</td>
#       <td id="T_a12e7_row0_col13" class="data row0 col13" >0.230</td>
#       <td id="T_a12e7_row0_col14" class="data row0 col14" >0.538</td>
#       <td id="T_a12e7_row0_col15" class="data row0 col15" >0.835</td>
#       <td id="T_a12e7_row0_col16" class="data row0 col16" >1.143</td>
#       <td id="T_a12e7_row0_col17" class="data row0 col17" >1.108</td>
#       <td id="T_a12e7_row0_col18" class="data row0 col18" >0.800</td>
#       <td id="T_a12e7_row0_col19" class="data row0 col19" >0.504</td>
#       <td id="T_a12e7_row0_col20" class="data row0 col20" >0.195</td>
#       <td id="T_a12e7_row0_col21" class="data row0 col21" >0.000</td>
#       <td id="T_a12e7_row0_col22" class="data row0 col22" >0.000</td>
#       <td id="T_a12e7_row0_col23" class="data row0 col23" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a12e7_level0_row1" class="row_heading level0 row1" >40_unity_masuwa_600km_exon</th>
#       <td id="T_a12e7_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_a12e7_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_a12e7_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_a12e7_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_a12e7_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_a12e7_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_a12e7_row1_col6" class="data row1 col6" >0.106</td>
#       <td id="T_a12e

# %%
pd.DataFrame(positive_topic_model.get_topic(0),columns=["Word","Score"])
# Out:
#           Word     Score
# 0         fair  0.061351
# 1         free  0.056762
# 2     election  0.020133
# 3       zambia  0.016629
# 4      zambian  0.016425
# 5       appeal  0.015518
# 6         need  0.013732
# 7  transparent  0.013007
# 8     credible  0.011525
# 9   opposition  0.011313
